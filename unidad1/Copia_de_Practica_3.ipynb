# %% [markdown]
# <a href="https://colab.research.google.com/github/25041033Joshua/Probabilidad-y-estadistica/blob/main/unidad1/Copia_de_Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 1
#
# ##Facilitador:Jose Gabriel Rodriguez Rivas
#
# #Alumno:Joshua Josey García Hernández

# %% [markdown]
# #Practica 3: Tablas de Frecuencia

# %%
#basado en el LIBRO estadistiaca para administrarcion pagina 12
#creamos una lista vacia que representa la edad de 100 personas
import random
edades=[]
#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
  #generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  #numero_aleatorio
  numero_aleatorio=random.randint(18,70)
  #Agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
#imprimimos la lista de edades
print(edades)
# Out:
# [66, 58, 42, 41, 49, 42, 47, 47, 50, 39, 63, 53, 56, 42, 69, 48, 69, 30, 48, 55, 25, 25, 37, 47, 50, 21, 46, 49, 19, 20, 44, 28, 66, 31, 53, 28, 26, 45, 68, 37, 52, 50, 33, 54, 20, 61, 48, 58, 48, 70, 50, 55, 54, 28, 61, 62, 70, 50, 31, 44, 67, 52, 65, 23, 36, 21, 38, 56, 26, 20, 44, 62, 28, 23, 49, 21, 53, 28, 48, 53, 24, 44, 46, 43, 69, 25, 19, 34, 63, 68, 48, 70, 41, 41, 49, 55, 68, 51, 69, 34]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los números aleatorios
df=pd.DataFrame(edades,columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    66
# 1    58
# 2    42
# 3    41
# 4    49

# %%
#Calcular la tabla de distribucion de frecuencias
tabla_frecuencias=df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='Edad')

#Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 25    19           2
# 15    20           3
# 14    21           3
# 30    23           2
# 39    24           1
# 12    25           3
# 22    26           2
# 2     28           5
# 33    30           1
# 23    31           2
# 35    33           1
# 26    34           2
# 36    36           1
# 21    37           2
# 38    38           1
# 31    39           1
# 7     41           3
# 9     42           3
# 40    43           1
# 3     44           4
# 32    45           1
# 20    46           2
# 8     47           3
# 0     48           6
# 5     49           4
# 1     50           5
# 41    51           1
# 29    52           2
# 4     53           4
# 28    54           2
# 13    55           3
# 24    56           2
# 17    58           2
# 27    61           2
# 18    62           2
# 19    63           2
# 37    65           1
# 16    66           2
# 34    67           1
# 11    68           3
# 6     69           4
# 10    70           3

# %%
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 25    19           2           0.02
# 15    20           3           0.03
# 14    21           3           0.03
# 30    23           2           0.02
# 39    24           1           0.01
# 12    25           3           0.03
# 22    26           2           0.02
# 2     28           5           0.05
# 33    30           1           0.01
# 23    31           2           0.02
# 35    33           1           0.01
# 26    34           2           0.02
# 36    36           1           0.01
# 21    37           2           0.02
# 38    38           1           0.01
# 31    39           1           0.01
# 7     41           3           0.03
# 9     42           3           0.03
# 40    43           1           0.01
# 3     44           4           0.04
# 32    45           1           0.01
# 20    46           2           0.02
# 8     47           3           0.03
# 0     48           6           0.06
# 5     49           4           0.04
# 1     50           5           0.05
# 41    51           1           0.01
# 29    52           2           0.02
# 4     53           4           0.04
# 28    54           2           0.02
# 13    55           3           0.03
# 24    56           2           0.02
# 17    58           2           0.02
# 27    61           2           0.02
# 18    62           2           0.02
# 19    63           2           0.02
# 37    65           1           0.01
# 16    66           2           0.02
# 34    67           1           0.01
# 11    68           3           0.03
# 6     69           4           0.04
# 10    70           3           0.03

# %%
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 25    19           2           0.02              2.0
# 15    20           3           0.03              3.0
# 14    21           3           0.03              3.0
# 30    23           2           0.02              2.0
# 39    24           1           0.01              1.0
# 12    25           3           0.03              3.0
# 22    26           2           0.02              2.0
# 2     28           5           0.05              5.0
# 33    30           1           0.01              1.0
# 23    31           2           0.02              2.0
# 35    33           1           0.01              1.0
# 26    34           2           0.02              2.0
# 36    36           1           0.01              1.0
# 21    37           2           0.02              2.0
# 38    38           1           0.01              1.0
# 31    39           1           0.01              1.0
# 7     41           3           0.03              3.0
# 9     42           3           0.03              3.0
# 40    43           1           0.01              1.0
# 3     44           4           0.04              4.0
# 32    45           1           0.01              1.0
# 20    46           2           0.02              2.0
# 8     47           3           0.03              3.0
# 0     48           6           0.06              6.0
# 5     49           4           0.04              4.0
# 1     50           5           0.05              5.0
# 41    51           1           0.01              1.0
# 29    52           2           0.02              2.0
# 4     53           4           0.04              4.0
# 28    54           2           0.02              2.0
# 13    55           3           0.03              3.0
# 24    56           2           0.02              2.0
# 17    58           2           0.02              2.0
# 27    61           2           0.02              2.0
# 18    62           2           0.02              2.0
# 19    63           2           0.02              2.0
# 37    65           1           0.01              1.0
# 16    66           2           0.02              2.0
# 34    67           1           0.01              1.0
# 11    68           3           0.03              3.0
# 6     69           4           0.04              4.0
# 10    70           3           0.03              3.0

# %%
tabla_frecuencias['Frec Acumulada']=tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 25    19           2           0.02              2.0               2
# 15    20           3           0.03              3.0               5
# 14    21           3           0.03              3.0               8
# 30    23           2           0.02              2.0              10
# 39    24           1           0.01              1.0              11
# 12    25           3           0.03              3.0              14
# 22    26           2           0.02              2.0              16
# 2     28           5           0.05              5.0              21
# 33    30           1           0.01              1.0              22
# 23    31           2           0.02              2.0              24
# 35    33           1           0.01              1.0              25
# 26    34           2           0.02              2.0              27
# 36    36           1           0.01              1.0              28
# 21    37           2           0.02              2.0              30
# 38    38           1           0.01              1.0              31
# 31    39           1           0.01              1.0              32
# 7     41           3           0.03              3.0              35
# 9     42           3           0.03              3.0              38
# 40    43           1           0.01              1.0              39
# 3     44           4           0.04              4.0              43
# 32    45           1           0.01              1.0              44
# 20    46           2           0.02              2.0              46
# 8     47           3           0.03              3.0              49
# 0     48           6           0.06              6.0              55
# 5     49           4           0.04              4.0              59
# 1     50           5           0.05              5.0              64
# 41    51           1           0.01              1.0              65
# 29    52           2           0.02              2.0              67
# 4     53           4           0.04              4.0              71
# 28    54           2           0.02              2.0              73
# 13    55           3           0.03              3.0              76
# 24    56           2           0.02              2.0              78
# 17    58           2           0.02              2.0              80
# 27    61           2           0.02              2.0              82
# 18    62           2           0.02              2.0              84
# 19    63           2           0.02              2.0              86
# 37    65           1           0.01              1.0              87
# 16    66           2           0.02              2.0              89
# 34    67           1           0.01              1.0              90
# 11    68           3           0.03              3.0              93
# 6     69           4           0.04              4.0              97
# 10    70           3           0.03              3.0             100

# %%
# Importamos la libreria math de funciones matematicas
import math

# %%
# Volvemois a usar la lista edades
print(edades)
# Out:
# [66, 58, 42, 41, 49, 42, 47, 47, 50, 39, 63, 53, 56, 42, 69, 48, 69, 30, 48, 55, 25, 25, 37, 47, 50, 21, 46, 49, 19, 20, 44, 28, 66, 31, 53, 28, 26, 45, 68, 37, 52, 50, 33, 54, 20, 61, 48, 58, 48, 70, 50, 55, 54, 28, 61, 62, 70, 50, 31, 44, 67, 52, 65, 23, 36, 21, 38, 56, 26, 20, 44, 62, 28, 23, 49, 21, 53, 28, 48, 53, 24, 44, 46, 43, 69, 25, 19, 34, 63, 68, 48, 70, 41, 41, 49, 55, 68, 51, 69, 34]

# %%
# Crear un DataFrame con las edades
df=pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     66
# 1     58
# 2     42
# 3     41
# 4     49
# ..   ...
# 95    55
# 96    68
# 97    51
# 98    69
# 99    34
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n=len(edades)
k=int(1+math.log2(n))
print("Valor de n=",n,"\nNúmero de intervalos",k)
# Out:
# Valor de n= 100
# Número de intervalos 7

# %%
# Crear la tabla de frecuencia
tabla_frecuencias=pd.cut(df['Edad'],bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns=['Clase', 'Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0  (40.857, 48.143]    23
# 1  (48.143, 55.429]    21
# 2  (18.948, 26.286]    16
# 3    (62.714, 70.0]    16
# 4  (26.286, 33.571]     9
# 5  (55.429, 62.714]     8
# 6  (33.571, 40.857]     7

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencias=tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 2  (18.948, 26.286]    16
# 4  (26.286, 33.571]     9
# 6  (33.571, 40.857]     7
# 0  (40.857, 48.143]    23
# 1  (48.143, 55.429]    21
# 5  (55.429, 62.714]     8
# 3    (62.714, 70.0]    16

# %%
# Generar columnas siguientes
tabla_frecuencias['Frec Relativa']=tabla_frecuencias['Frec']/n
tabla_frecuencias['Frec Porcentual']=tabla_frecuencias['Frec']/n *100
tabla_frecuencias['Frec Ac']=tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac']=tabla_frecuencias['Frec Relativa'].cumsum()
tabla_frecuencias['Frec Porcentual Ac']=tabla_frecuencias['Frec Porcentual'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencias)
# Out:
#               Clase  Frec  Frec Relativa  Frec Porcentual  Frec Ac  \
# 2  (18.948, 26.286]    16           0.16             16.0       16
# 4  (26.286, 33.571]     9           0.09              9.0       25
# 6  (33.571, 40.857]     7           0.07              7.0       32
# 0  (40.857, 48.143]    23           0.23             23.0       55
# 1  (48.143, 55.429]    21           0.21             21.0       76
# 5  (55.429, 62.714]     8           0.08              8.0       84
# 3    (62.714, 70.0]    16           0.16             16.0      100
#
#    Frec Rel Ac  Frec Porcentual Ac
# 2         0.16                16.0
# 4         0.25                25.0
# 6         0.32                32.0
# 0         0.55                55.0
# 1         0.76                76.0
# 5         0.84                84.0
# 3         1.00               100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades,alpha=0.5)
plt.title("Histograma de edades basado en la funcion de matplolib con valores estandar")

# The Text object call was likely intended to display text on a plot,
# but it's not a standalone function call outside of a plot context.
# Removing it for now or it can be integrated with matplotlib if needed.
# Text(0.5,1.0, 'Histograma de edades basado en la funcion de matplolib con valores estandar ')
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplolib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'],bins=k, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
