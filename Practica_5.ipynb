# %% [markdown]
# <a href="https://colab.research.google.com/github/25041033Joshua/Probabilidad-y-estadistica/blob/main/Practica_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 1
#
# ##Facilitador:Jose Gabriel Rodriguez Rivas
#
# #Alumno:Joshua Josey García Hernández
#
# ##Programa 5: Estadística básica e histograma

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot

# %%
covid=pd.read_csv("/content/20-06-30-COVID19MEXICO - codificado.csv", encoding="ISO-8859-1")
# Out:
#   File "/tmp/ipython-input-2639632448.py", line 2
#     covid=pd.read_csv,("20-60-30-COVID19MEXICO - codificado.cvs," encoding="ISO-8859-1")
#                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Mostrar los primeros 5 registros del archivo
covid.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1833996184.py in <cell line: 0>()
#       1 #Mostrar los primeros 5 registros del archivo
# ----> 2 covid.head()
#
# NameError: name 'covid' is not defined

# %%
# Mostrar la informacion del archivo.
# Muestra el numero de registros, tipos de datos de la columna, valores nulos, memoria utilizada, etc
 covid.info()

# %%
# Mostrar la edad maxima de la base de datos de la columna edad
covid.EDAD.max()

# %%
# Mostrar la edad minima de la base de datos de la columna edad
covid.EDAD.min()

# %%
# Dibuja el histograma del atributo "EDAD" con bins = 3
# Calcular la media y guardarla en una variable para mostrarla en el histograma
media=covid.EDAD.mean()
plt.pyplot.hist(covid.EDAD, bins = 11)
plt.pyplot.title("Histograma EDAD Pruebas COVID")
plt.pyplot.axvline(media, color='y', linestyle='dashed',linewidth=2, label=f'Media={media:.2f}')
plt.pyplot.xlabel("Edad")
plt.pyplot.ylabel("Frecuencia")

# %%
# Dibuja el histograma de la columna sexo,
# sexo permite comparar cuantos hay de cada grupo
plt.pyplot.hist(covid.SEXO, bins = 3)

# establece las etiquetas x/y y muestra el titulo
plt.pyplot.title("Histograma SEXO de Pruebas COVID ")
plt.pyplot.xlabel("Sexo")
plt.pyplot.ylabel("Frecuencia")

# %%
# Dibuja el histograma del atributo "Tipo Paciente",
# comparar cuantos hay de cada grupo
plt.pyplot.hist(covid.TIPO_PACIENTE, bins = 3)

# establece las etiquetas x/y y muestra el titulo
plt.pyplot.title("Histograma de tipos Pacientes de Pruebas COVID ")
plt.pyplot.xlabel("Tipo de Paciente")
plt.pyplot.ylabel("Frecuencia")

# %%
# Crear un diagram de cajas para visualizar la distribucion
# de los rangos de edad por sexo
sns.boxplot(x="SEXO", y="EDAD", data=covid)

# %%
# Crear un diagram de cajas para visualizar la distribucion
# de los rangos de edad por paciente
sns.boxplot(x="TIPO_PACIENTE", y="EDAD", data=covid)

# %%
# Crear un diagram de cajas para visualizar la distribucion
# de los rangos de edad por paciente
sns.boxplot(x="RESULTADO", y="EDAD", data=covid)
