# %% [markdown]
# <a href="https://colab.research.google.com/github/25041033Joshua/Probabilidad-y-estadistica/blob/main/unidad3/Ejercicio_1_U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 3
#
# ##Facilitador:Jose Gabriel Rodriguez Rivas
#
# #Alumno:Joshua Josey García Hernández
#
# ##Ejercicio 1

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
X=[0,1,2,3,4,5] #Valores posibles de la variable aleatoria
p=[0.10,0.25,0.30,0.20,0.10,0.05] #Probabilidades correspondientes

suma= np.sum(p)
print(round(suma,2))
# Out:
# 1.0

# %%
X=[0,1,2,3,4,5] #Valores posibles de la variable aleatoria
p=[0.10,0.25,0.30,0.20,0.10,0.05] #Probabilidades correspondientes

#Inicializar una variable para acumular la suma
valor_esperado=0

#Recorrer los valores y sus probabilidades
for i in range(len(X)): # Corrected indentation and used X instead of x
  xi=X[i]   #Valor de la variable aleatoria
  pi=p[i]   #Probabilidad de ese valor
  producto = xi*pi     #multiplicar valor por su probabilidad
  valor_esperado += producto #sumar al acumulador - Corrected line
  #Mostrar cada paso
  print(f"x={xi},p={pi},x*p={producto:.2f}")

#Mostrar resultado final
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}") # Corrected indentation
# Out:
# x=0,p=0.1,x*p=0.00
# x=1,p=0.25,x*p=0.25
# x=2,p=0.3,x*p=0.60
# x=3,p=0.2,x*p=0.60
# x=4,p=0.1,x*p=0.40
# x=5,p=0.05,x*p=0.25
#
# Valor esperado (Esperanza): 2.10

# %%
x=[0,1,2,3,4,5]
p=[0.10,0.25,0.30,0.20,0.10,0.05]

#Calcular E(X)
esperanza=0
for i in range(len(x)):
  esperanza+=x[i]*p[i]

#Calcular E(X^2)
esperanza_cuadrado=0
for i in range(len(x)):
  esperanza_cuadrado+= (x[i]**2)*p[i]

#Calcular varianza y desviación estándar
varianza = esperanza_cuadrado-esperanza**2
desviacion= math.sqrt(varianza)

#Mostrar resultados
print(f"E(X)={esperanza:.2f}")
print(f"E(X^2)={esperanza_cuadrado:.2f}")
print(f"Varianza={varianza:.2f}")
print(f"Desviación estándar={desviacion:.2f}")
# Out:
# E(X)=2.10
# E(X^2)=6.10
# Varianza=1.69
# Desviación estándar=1.30

# %%
#-------------------------------------------------
#Gráfica de una distribución de probabilidad discreta
#con media, varianza y desviación estándar
#--------------------------------------------------

import matplotlib.pyplot as plt
import numpy as np

#Datos: valores de la variable aleatoria y sus probabilidades
x=np.array([0,1,2,3,4,5])
p=np.array([0.10,0.25,0.30,0.20,0.10,0.05])

#Cálculo del valor esperado (media)
esperanza=np.sum(x*p)

#Cálculo de la esperanza del cuadrado
esperanza_cuadrado=np.sum(x**2*p)

#Cálculo de la varianza y desviación estándar
varianza=esperanza_cuadrado-esperanza**2
desviacion=np.sqrt(varianza)

#Mostrar los resultados en consola
print(f"E(X)={esperanza:.2f}")
print(f"E(X^2)={esperanza_cuadrado:.2f}")
print(f"Varianza={varianza:.2f}")
print(f"Desviacion estándar={desviacion:.2f}")

#Crear la gráfica tipo 'stem' (tallos y hojas)
plt.stem(x,p,basefmt=" ",linefmt='b-',markerfmt='bo')
plt.title("Distribución de Probabilidad Discreta\ncon Media y Desviación Estándar")
plt.xlabel("Valores de la variable aleatoria X")
plt.ylabel("P(X)")
plt.grid(True, linestyle='--',alpha=0.6)

#Dibujar línea vertical en la media
plt.axvline(x=esperanza,color='red',linestyle='--',label=f"Media (E[X])={esperanza:.2f}")

#Resaltar el rango de -+1 desviación estándar
plt.axvspan(esperanza - desviacion, esperanza + desviacion, color='red',alpha=0.2, label=f"-+1 Desv. Estándar (o={desviacion:.2f})")

#Mostrar leyenda y límites
plt.legend()
plt.ylim(0,max(p)+0.05)
plt.xticks(x)

#Mostrar la gráfica
plt.show()
# Out:
# E(X)=2.10
# E(X^2)=6.10
# Varianza=1.69
# Desviacion estándar=1.30

# %%
x=[0,1,2,3,4,5] #Valores posibles de la variable aleatoria
p=[0.10,0.25,0.30,0.20,0.10,0.05] #Probabilidades correspondientes

#Calcular función acumulada
F=np.cumsum(p)

#Mostrar resultados
for xi,fi in zip(x,F):
  print(f"F({xi})={fi:.2f}")

#Graficar
plt.step(x,F,where='post')
plt.title("Función de Distribución Acumulada (FDA)")
plt.xlabel("Calificación")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.ylim(0,1.05)
plt.show()
# Out:
# F(0)=0.10
# F(1)=0.35
# F(2)=0.65
# F(3)=0.85
# F(4)=0.95
# F(5)=1.00

# %% [markdown]
# #¿Cuál es el promedio esperado de células anormales por muestra?
# ##Es de 2.10

# %% [markdown]
# #¿Existe mucha variabilidad entre muestras?
# ##Es moderada pues es de 1.3

# %% [markdown]
# #¿Qué indica la función acumulada sobre la probabilidad de encontrar un número bajo o alto de células anormales ?
# ##Es alta la probabilidad
