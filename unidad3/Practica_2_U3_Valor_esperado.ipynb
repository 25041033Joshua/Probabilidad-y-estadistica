# %% [markdown]
# <a href="https://colab.research.google.com/github/25041033Joshua/Probabilidad-y-estadistica/blob/main/unidad3/Practica_2_U3_Valor_esperado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica
#
# ##Unidad 3
#
# ##Facilitador:Jose Gabriel Rodriguez Rivas
#
# #Alumno:Joshua Josey García Hernández
#
# ##Valor esperado

# %%
X=[5,6,7,8,9,10] #Valores posibles de la variable aleatoria
p=[0.05,0.10,0.20,0.30,0.25,0.10] #Probabilidades correspondientes

#Inicializar una variable para acumular la suma
valor_esperado=0

#Recorrer los valores y sus probabilidades
for i in range(len(X)): # Corrected indentation and used X instead of x
  xi=X[i]   #Valor de la variable aleatoria
  pi=p[i]   #Probabilidad de ese valor
  producto = xi*pi     #multiplicar valor por su probabilidad
  valor_esperado += producto #sumar al acumulador - Corrected line
  #Mostrar cada paso
  print(f"x={xi},p={pi},x*p={producto:.2f}")

#Mostrar resultado final
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}") # Corrected indentation
# Out:
# x=5,p=0.05,x*p=0.25
# x=6,p=0.1,x*p=0.60
# x=7,p=0.2,x*p=1.40
# x=8,p=0.3,x*p=2.40
# x=9,p=0.25,x*p=2.25
# x=10,p=0.1,x*p=1.00
#
# Valor esperado (Esperanza): 7.90
